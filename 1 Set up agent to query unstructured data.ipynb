# %% [markdown]
# # Set up agent for querying unstructured data
#
# Find a bunch of related PDFs online that may be relevant to a specific use case you're currently driving or looking to consider in future. For example; financial statements, public reports.
#
# We will now use Agent Bricks Knowledge Assistant to create a RAG application without knowing all the technical knobs and whistles. Let's see how we can do that by querying unstructured data on the Databricks platform...

# %% [markdown]
# # Examples of documents you can look at
#
# - Product - technical specifications
#
# - Marketing - Marketing Intelligence reports, Internal or exterior competitor analysis
#
# - Manufacturing - summary of asset maintenance reports conducted by external parties

# %% [markdown]
# # Upload Assets to Volume
#
# 1. Within the schema, create a Volume asset.
#
# 2. Within the Volume, upload your PDF documents.

# %% [markdown]
# # Agent Bricks
#
# Select the Knowledge Assistant brick.
#
# Fill in natural language on what you want the agent to do.
