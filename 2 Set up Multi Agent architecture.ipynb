# %% [markdown]
# # Set up Multi Agent architecture
#
# You can use Agent Bricks Multi Agent Supervisor to bring your Genie spaces and Knowledge Assistant agents together into a seamless experience.

# %% [markdown]
# # Final Remarks
#
# Is this all possible if you want to customise certain aspects of the Agent (e.g. chunking algorithm, embedding and retrieval model)?
#
# Yes - use the Agent Framework.
